# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import random

DIR='E:/images1024x1024'
FFHQ_data=[]

def get_data():
    for img in os.listdir(DIR):
        #print(img)
        try:
            img_array=cv2.imread(os.path.join(DIR,img))
            img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
            new_array=cv2.resize(img_array,(224,224))
            FFHQ_data.append(new_array)
            #training_data.append(img_array)
        except Exception as e:
            pass
get_data()
random.shuffle(FFHQ_data)

# %%
FFHQ=np.array(FFHQ_data)

# %%
FFHQ.shape
# Out:
# (1000, 224, 224, 3)

# %%
plt.imshow(FFHQ[0])

# %%
import pickle
file = open('data/image_dump', 'wb')

data = pickle.dump(FFHQ,file)
